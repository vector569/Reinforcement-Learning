# %%
import numpy as np
import grid

# %%
obj = grid.Gridworld(3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-50aac0ce462d> in <module>()
# ----> 1 obj = grid.Gridworld(3,5)
#
# TypeError: __init__() takes from 1 to 2 positional arguments but 3 were given

# %%
obj.grid
# Out:
# [[1, 0.5630000058077147, ['T', 'R']],
#  [2, 0.46854427544216826, ['T', 'R', 'L']],
#  [3, 0.5506501531422914, ['T', 'L']],
#  [4, -0.8191368686655669, ['T', 'R', 'B']],
#  [5, 0.02642084698604341, ['T', 'R', 'B', 'L']],
#  [6, 0.09274875183005271, ['T', 'B', 'L']],
#  [7, -0.13662702764209733, ['R', 'B']],
#  [8, 0.5472517598676137, ['R', 'B', 'L']],
#  [9, -0.3035291206801778, ['B', 'L']]]
